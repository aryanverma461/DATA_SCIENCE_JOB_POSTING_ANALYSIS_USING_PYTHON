# %%
# Importing Libraries
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt  

# Loading Data
parquet_file= r'C:\Users\verma\OneDrive\Desktop\PYTHON_DATA_PROJECT\1_Data_science_job_postings_dataset\0000.parquet'
df = pd.read_parquet(parquet_file, engine='auto')

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df.head()
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location     job_posted_date  \
# ...

# %%
df_salary = df.copy()
yearly_median_salary = df_salary.salary_year_avg.median()
yearly_median_salary
# Out:
# 115000.0

# %%
df_salary['salary_year_avg']=df_salary['salary_year_avg']
# .fillna(yearly_median_salary)

# %%
df_salary_mean = df_salary.pivot_table(index='job_country', columns='job_title_short', values='salary_year_avg',aggfunc='median')

# %%
# Calculating top 5 Countries with value counts
Top_5_country = df_salary.job_country.value_counts().head().index
Top_5_country.to_list()
# Out:
# ['United States', 'India', 'United Kingdom', 'France', 'Germany']

# %%
df_job_country_salary = df_salary_mean.loc[Top_5_country]
df_job_country_salary
# Out:
# job_title_short  Business Analyst  Cloud Engineer  Data Analyst  \
# job_country
# United States             90000.0        116100.0       90000.0
# India                     64800.0             NaN      100500.0
# United Kingdom            56700.0             NaN       87750.0
# France                    89100.0        105968.0       69175.0
# Germany                   89100.0         89100.0      103750.0
#
# job_title_short  Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_country
# United States         125000.0        130000.0                   150000.0
# India                 147500.0        114008.0                    79200.0
# United Kingdom        110000.0        105300.0                   149653.0
# France                 98301.5         88128.0                    80850.0
# Germany               147500.0        131560.0                    89100.0
#
# job_title_short  Senior Data Analyst  Senior Data Engineer  \
# job_country
# ...

# %%
top_job_titles = ['Data Analyst', 'Business Analyst', 'Data Engineer']

# %%
df_plot = df_job_country_salary[top_job_titles]
df_plot
# Out:
# job_title_short  Data Analyst  Business Analyst  Data Engineer
# job_country
# United States         90000.0           90000.0       125000.0
# India                100500.0           64800.0       147500.0
# United Kingdom        87750.0           56700.0       110000.0
# France                69175.0           89100.0        98301.5
# Germany              103750.0           89100.0       147500.0

# %%
df_plot.plot(kind='bar')
ax =plt.gca()
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, _:f'${int(x/1000)}K'))
plt.title('Median salary By Top 5 Countries')
plt.xlabel('')
plt.xticks(rotation = 45)
plt.ylabel('Median Salary ($USD)')
plt.tight_layout()
